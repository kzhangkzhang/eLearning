# %% [markdown]
# [A good Resource](https://www.tutorialspoint.com/python/python_exceptions.htm)

# %%
from IPython.display import display, Image

# %%
Image("Kevin_ErrorHandling.png")

# %%
Image("Kevin_ErrorHandling_Finally.png")

# %%
2 + 's'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-842879d18793> in <module>()
# ----> 1 2 + 's'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    2 + 's'
except TypeError:
    print "Kevin - there was type error!"
finally:
    print "Kevin - finally this is printed"
    
print "continuing execute code after above ..."
# Out:
# Kevin - there was type error!
# Kevin - finally this is printed
# continuing execute code after above ...

# %% [markdown]
# You can check out the full list of built-in exceptions [here](https://docs.python.org/2/library/exceptions.html). now lets learn how to handle errors and exceptions in our own code.

# %%
try:
    f = open('testfile.txt', 'a+')
    f.write('\nTest write this again')
except:
    print 'Kevin - error in writing to the file'
else:
    print 'Kevin - file write is good'
# Out:
# Kevin - file write is good

# %% [markdown]
# Great! Now we don't actually need to memorize that list of exception types! Now what if we kept wanting to run code after the exception occurred? This is where **finally** comes in.
# ##finally
# The finally: block of code will always be run regardless if there was an exception in the try code block. The syntax is:
#
#     try:
#        Code block here
#        ...
#        Due to any exception, this code may be skipped!
#     finally:
#        This code block would always be executed.
#
# For example:

# %%
try:
    f = open('testfile2', 'r')
    f.write("test write statement")
except:
    print 'there is a an error'
finally:
    print "Kevin - always execute finally code blocks even there is an exception"
# Out:
# there is a an error
# Kevin - always execute finally code blocks even there is an exception

# %%
def askint():
        try:
            val = int(raw_input("Please enter an integer: "))
        except:
            print "Looks like you did not enter an integer!"
            val = int(raw_input("Try again-Please enter an integer: "))
        finally:
            print "Finally, I executed!"
        print val

# %%
askint()
# Out:
# Please enter an integer: a
# Looks like you did not enter an integer!
# Try again: please enter an interger: a
# Finally, I executed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-6ee53d339e7e> in <module>()
# ----> 1 askint()
#
# <ipython-input-19-1d9444774fc8> in askint()
#       4     except:
#       5         print "Looks like you did not enter an integer!"
# ----> 6         val = int(raw_input("Try again: please enter an interger: "))
#       7     finally:
#       8         print "Finally, I executed"
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
def askint2():
    while True:
        try:
            val = int(raw_input("Please enter an integer: "))
        except:
            print "Looks like you did not enter an integer!"
            continue
        else:
            print 'Yep that is an interger. thank you!'
            break
        finally:
            print "Finally, I executed!"
            
        print val

# %%
askint2()
# Out:
# Please enter an integer: five
# Looks like you did not enter an integer!
# Finally, I executed!
# Please enter an integer: four
# Looks like you did not enter an integer!
# Finally, I executed!
# Please enter an integer: 3
# Yep that is an interger. thank you!
# Finally, I executed!
